# %%
import requests
import re
import pandas as pd
import os
from datetime import date
import datetime
import json

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Settings

# %%
sns.set_style("white")
flatui = ['#1b9e77','#d95f02','#7570b3','#e7298a','#66a61e','#e6ab02']
#flatui = ['#e41a1c','#377eb8','#4daf4a','#984ea3','#ff7f00','#ffff33']
#flatui = ['#7fc97f','#beaed4','#fdc086','#ffff99','#386cb0','#f0027f']
sns.set_palette(flatui)

sns.set_style("white")
flatui = ['#1b9e77','#d95f02','#7570b3','#e7298a','#66a61e','#e6ab02']
#flatui = ['#e41a1c','#377eb8','#4daf4a','#984ea3','#ff7f00','#ffff33']
#flatui = ['#7fc97f','#beaed4','#fdc086','#ffff99','#386cb0','#f0027f']
sns.set_palette(flatui)

# %% [markdown]
# # Read the data

# %%
df = pd.read_csv(os.path.join("data", "sc_weather.csv"))

# %%
df.columns
# Out:
# Index(['sensor_id', 'sensor_type', 'location', 'lat', 'lon', 'timestamp',
#        'date', 'time', 'hour', 'day', 'weekend', 'P1', 'P2', 'temp', 'tempmax',
#        'tempmin', 'conditions', 'weather'],
#       dtype='object')

# %% [markdown]
# # Weekend

# %%
sns.catplot(data=df, y='P1', x='sensor_id', hue="weekend", kind="violin", palette = flatui, cut=0)
f = plt.gcf()
f.set_size_inches(15,10)
plt.show()

# %%
sns.catplot(data=df, y='P2', x='sensor_id', hue="weekend", kind="violin", palette = flatui, cut=0)
f = plt.gcf()
f.set_size_inches(15,10)
plt.show()

# %% [markdown]
# # Hourly distribution

# %%
for sensor_id in df.sensor_id.unique():
    sns.scatterplot(data=df[df.sensor_id == sensor_id], y='P1', x='time', s=15, alpha=0.5, palette = flatui[:2])

    f = plt.gcf()
    f.set_size_inches(15,10)
    plt.xlabel("Time of day")
    plt.ylabel("P1")
    plt.title(f"P1({sensor_id})")
    
    
    plt.xticks(np.arange(25), np.arange(25))
    #plt.legend(routes.astype(str))
    plt.show()

# %%
for sensor_id in df.sensor_id.unique():
    sns.scatterplot(data=df[df.sensor_id == sensor_id], y='P2', x='time', s=15, alpha=0.5, palette = flatui[:2])

    f = plt.gcf()
    f.set_size_inches(15,10)
    plt.xlabel("Time of day")
    plt.ylabel("P2")
    plt.title(f"P2({sensor_id})")
    
    
    plt.xticks(np.arange(25), np.arange(25))
    #plt.legend(routes.astype(str))
    plt.show()

# %%
sns.catplot(data=df, y='P1', x='sensor_id', hue="hour", kind="violin", palette = flatui, cut=0)
f = plt.gcf()
f.set_size_inches(20,10)
plt.show()

# %%
sns.catplot(data=df, y='P2', x='sensor_id', hue="hour", kind="violin", palette = flatui, cut=0)
f = plt.gcf()
f.set_size_inches(20,10)
plt.show()

# %% [markdown]
# # Weather

# %%
sns.catplot(data=df, y='P1', x='sensor_id', hue="weather", kind="violin", palette = flatui, cut=0)
f = plt.gcf()
f.set_size_inches(15,10)
plt.show()

# %%
sns.catplot(data=df, y='P2', x='sensor_id', hue="weather", kind="violin", palette = flatui, cut=0)
f = plt.gcf()
f.set_size_inches(15,10)
plt.show()
