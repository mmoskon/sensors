# %%
import requests
import re
import pandas as pd
import os
from datetime import date
import datetime
import json

# %%
df = pd.read_csv(os.path.join("data", "sc_weather.csv"))

# %%
df
# Out:
#        sensor_id sensor_type  location     lat     lon            timestamp  \
# 0          74650      SDS011     63169  46.042  14.592  2022-09-01 00:04:32
# 1          74650      SDS011     63169  46.042  14.592  2022-09-01 00:07:00
# 2          74650      SDS011     63169  46.042  14.592  2022-09-01 00:09:25
# 3          74650      SDS011     63169  46.042  14.592  2022-09-01 00:11:52
# 4          74650      SDS011     63169  46.042  14.592  2022-09-01 00:14:19
# ...          ...         ...       ...     ...     ...                  ...
# 49141      67867      SDS011     54672  46.096  14.470  2022-10-25 23:49:16
# 49142      67867      SDS011     54672  46.096  14.470  2022-10-25 23:51:41
# 49143      67867      SDS011     54672  46.096  14.470  2022-10-25 23:54:07
# 49144      67867      SDS011     54672  46.096  14.470  2022-10-25 23:56:33
# 49145      67867      SDS011     54672  46.096  14.470  2022-10-25 23:59:00
#
# ...
